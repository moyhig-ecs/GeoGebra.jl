# %%
ENV["JULIA_DEBUG"]="GeoGebra"
# Out:
# "GeoGebra"

# %%
using Pkg
Pkg.activate("/Users/manabu/work/ggblab/julia/GeoGebra.jl")  # または Pkg.activate(pwd())
Pkg.instantiate()
using GeoGebra
# Out:
#   Activating project at `~/work/ggblab/julia/GeoGebra.jl`

# %%
inject_applet()
# Out:
# [ Info: Listening on: 127.0.0.1:61613, thread id: 1
# Dict{String, Any} with 5 entries:
#   "kernelId"   => "84f8ac5a-ac27-44f9-926f-39273bfbc3c1"
#   "wsPort"     => 0xf0ad
#   "insertMode" => "split-right"
#   "type"       => "inject"
#   "appName"    => "suite"

# %%
@ggb O = (0, 0)
# Out:
# O
# Info: PersistentCounter disabled when called from Julia/PythonCall

# %%
@ggb :api getValueString(:O)
# Out:
# "O = (0, 0)"

# %%
@ggb Circle(:O, 6)
# Out:
# c

# %%
@ggb M = Point(c)
# Out:
# M

# %%
# @macroexpand 
@ggb r_1 = 12
# Out:
# r_1

# %%
@ggb r_2 = 9
# Out:
# r_2

# %%
@ggb Circle(:M, :r_1)
@ggb Circle(:M, :r_2)
# Out:
# e

# %%
@ggb {Tangent(:M, :c)}
# Out:
# l1

# %%
@ggb l1(1)
# Out:
# f

# %%
@ggb {Intersect(d, f)}
@ggb {Intersect(e, f)}
# Out:
# l3

# %%
@ggb "P = If(x(l2(1)) < x(M), l2(1), l2(2))"
# Out:
# P

# %%
@ggb "Q = If(x(l3(1)) > x(M), l3(1), l3(2))"
# Out:
# Q

# %%
@ggb {Tangent(c, P)}
# Out:
# l4

# %%
@ggb {Tangent(c, Q)}
# Out:
# l5

# %%
@ggb "If(Distance(M, l4(1)) > 0, l4(1), l4(2))"
# Out:
# g

# %%
@ggb "If(Distance(M, l5(1)) > 0, l5(1), l5(2))"
# Out:
# h

# %%
@ggb R = Intersect(g, h)
# Out:
# R

# %%
@ggb {Intersect(c, g)}
# Out:
# l6

# %%
@ggb {Intersect(c, h)}
# Out:
# l7

# %%
@ggb K = l6(1)
# Out:
# K

# %%
@ggb L = l7(1)
# Out:
# L

# %%
# @macroexpand 
@ggb :const
# Out:
# 22-element Vector{Tuple{Int64, String, Py}}:
#  (1, "O", '(0, 0)')
#  (2, "c", 'Circle(O, 6)')
#  (3, "M", 'Point(c)')
#  (4, "r_1", '12')
#  (5, "r_2", '9')
#  (6, "d", 'Circle(M, r_1)')
#  (7, "e", 'Circle(M, r_2)')
#  (8, "l1", '{Tangent(M, c)}')
#  (9, "f", 'l1(1)')
#  (10, "l2", '{Intersect(d, f)}')
#  (11, "l3", '{Intersect(e, f)}')
#  (12, "P", 'If(x(l2(1)) < x(M), l2(1), l2(2))')
#  (13, "Q", 'If(x(l3(1)) > x(M), l3(1), l3(2))')
#  (14, "l4", '{Tangent(P, c)}')
#  (15, "l5", '{Tangent(Q, c)}')
#  (16, "g", 'If(Distance(M, l4(1)) > 0, l4(1), l4(2))')
#  (17, "h", 'If(Distance(M, l5(1)) > 0, l5(1), l5(2))')
#  (18, "R", 'Intersect(g, h)')
#  (19, "l6", '{Intersect(c, g)}')
#  (20, "l7", '{Intersect(c, h)}')
#  (21, "K", 'l6(1)')
#  (22, "L", 'l7(1)')

# %%
using PythonCall

# %%
o = parse.(Float64, pyconvert(Vector{String}, refresh!(@ggb(:const("O"))).data["element"][0]["coords"][0].values()))[1:2]
# Out:
# 2-element Vector{Float64}:
#  0.0
#  0.0

# %%
m = parse.(Float64, pyconvert(Vector{String}, refresh!(@ggb(:const("M"))).data["element"][0]["coords"][0].values()))[1:2]
# Out:
# 2-element Vector{Float64}:
#   0.04064902297582786
#  -5.999862303164225

# %%
r = parse.(Float64, pyconvert(Vector{String}, refresh!(@ggb(:const("R"))).data["element"][0]["coords"][0].values()))[1:2]
# Out:
# 2-element Vector{Float64}:
#   132.0015572379798
#  1117.4737806432909

# %%
(r-m)' * (o-m)
# Out:
# 6735.323076923078

# %%
using LinearAlgebra

# %%
(r-m) ⋅ (o-m)
# Out:
# 6735.323076923078

# %%
@ggb r_1 = 4*sqrt(2)
@ggb r_2 = 3*sqrt(2)
# Out:
# r_2

# %%
r = parse.(Float64, pyconvert(Vector{String}, refresh!(@ggb(:const("R"))).data["element"][0]["coords"][0].values()))[1:2]
# Out:
# 2-element Vector{Float64}:
#   -37.63483495201175
#  -279.7765417539183

# %%
(r-m) ⋅ (o-m)
# Out:
# -1641.0909069083305

# %%
@ggb :api getValueString(:M)
# Out:
# "M = (-1.9131925735303, -5.6867999944247)"

# %%
@ggb :api getXML(:M)
# Out:
# "<element type=\"point\" label=\"M\">\n\t<show object=\"true\" label=\"true\"/>\n\t<objColor r=\"21\" g=\"101\" b=\"192\" alpha=\"0\"/>\n\t<layer val=\"0\"/>\n\t<labelMode val=\"0\"/>\n\t<animation step=\"0.1\" type=\"1\" playing=\"false\"/>\n\t<pointSize val=\"5\"/>\n\t<pointStyle val=\"0\"/>\n\t<coords x=\"-1.9131925735303397\" y=\"-5.686799994424664\" z=\"1\"/>\n</element>\n"

# %%
@ggb :api getXcoord(:M)
# Out:
# -1.9131925735303397

# %%
@ggb :api getYcoord(:M)
# Out:
# -5.686799994424664
